# %% [markdown]
# # Script for using pretrained diffusion model on Gum Stain Card Images

# %% [markdown]
# First install the requirements file into a new virtual environment.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# Setup the device according to your machine

# %%
from diffusers import DiffusionPipeline
import torch
device = "cuda"

# %% [markdown]
# Pulling the diffusion model from hugging face and setting up the generator pipeline

# %%
generator = DiffusionPipeline.from_pretrained(
    "megamp15/all_gum_stain_cards", torch_dtype=torch.float32, use_safetensors=True
).to(device)
# Out:
# c:\Users\pmahi\OneDrive\Desktop\MP\Drexel\Courses\CS591_592-900 - Capstone\GEN\.env\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/193 [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/516 [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/455M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Now we can generate cards!

# %%
image = generator().images[0]
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# c:\Users\pmahi\OneDrive\Desktop\MP\Drexel\Courses\CS591_592-900 - Capstone\GEN\.env\Lib\site-packages\diffusers\models\attention_processor.py:1279: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   hidden_states = F.scaled_dot_product_attention(

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=128x160>
